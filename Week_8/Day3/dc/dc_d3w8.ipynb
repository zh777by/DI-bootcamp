# %%
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize

file_path = 'pg11.txt'

with open(file_path, 'r', encoding='utf-8') as file:
    text = file.read()

# %%
nltk.download('punkt')
nltk.download('stopwords')

def preprocess_text(text):
    text = text.lower()

    text = re.sub(r'[^a-zA-Z\s\']', '', text)

    sentences = sent_tokenize(text)
    words = [word_tokenize(sentence) for sentence in sentences]

    stop_words = set(stopwords.words('english'))
    filtered_words = [[word for word in sentence if word not in stop_words] for sentence in words]

    return filtered_words

corpus = """
This is an example sentence with some non-words, such as 123 and @symbols.
It's important to clean them for proper text analysis!
"""

preprocessed_corpus = preprocess_text(corpus)
print(preprocessed_corpus)
# Out:
# [['example', 'sentence', 'nonwords', 'symbols', "'s", 'important', 'clean', 'proper', 'text', 'analysis']]
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import re

def preprocess_and_split(text):
    start_index = text.find("*** START")
    end_index = text.find("*** END")

    relevant_text = text[start_index:end_index]

    relevant_text = re.sub(r"\*\*\* START OF THE PROJECT GUTENBERG EBOOK.*?\*\*\*", "", relevant_text, flags=re.DOTALL)
    relevant_text = re.sub(r"\*\*\* END OF THIS PROJECT GUTENBERG EBOOK.*?\*\*\*", "", relevant_text, flags=re.DOTALL)
    relevant_text = re.sub(r"\[Illustration\]", "", relevant_text)

    sentences = relevant_text.split('\n')
    corpus = ' '.join(sentences)

    return corpus

corpus = preprocess_and_split(text)

print(corpus[:200])
# Out:
#       Alice’s Adventures in Wonderland  by Lewis Carroll  THE MILLENNIUM FULCRUM EDITION 3.0  Contents   CHAPTER I.     Down the Rabbit-Hole  CHAPTER II.    The Pool of Tears  CHAPTER III.   A Caucus-

# %%
from tensorflow.keras.preprocessing.text import Tokenizer

tokenizer = Tokenizer()

tokenizer.fit_on_texts([corpus])

vocabulary = tokenizer.word_index

total_words = len(vocabulary) + 1

print("Vocabulary:")
print(vocabulary)
print("\nTotal Words:", total_words)
# Out:
# Vocabulary:
# ...
