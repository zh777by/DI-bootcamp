# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from scipy import stats


file_path = 'adult.data'
column_names = ['age', 'workclass', 'fnlwgt', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country', 'income']
df = pd.read_csv('/Users/macbook/Desktop/DI_bootcamp/Week_8/Day3/dc/adult/adult.data', names=column_names, na_values=' ?')
df.head(50)
# Out:
#     age          workclass  fnlwgt      education  education-num  \
# 0    39          State-gov   77516      Bachelors             13
# 1    50   Self-emp-not-inc   83311      Bachelors             13
# 2    38            Private  215646        HS-grad              9
# 3    53            Private  234721           11th              7
# 4    28            Private  338409      Bachelors             13
# 5    37            Private  284582        Masters             14
# 6    49            Private  160187            9th              5
# 7    52   Self-emp-not-inc  209642        HS-grad              9
# 8    31            Private   45781        Masters             14
# 9    42            Private  159449      Bachelors             13
# 10   37            Private  280464   Some-college             10
# 11   30          State-gov  141297      Bachelors             13
# 12   23            Private  122272      Bachelors             13
# ...

# %%
df = pd.DataFrame(df)

# Select only the numerical columns for normalization
numerical_columns = df.select_dtypes(include=['int64']).columns
df[numerical_columns] = MinMaxScaler().fit_transform(df[numerical_columns])

# Select only the numerical columns for Z-score normalization
numerical_columns = df.select_dtypes(include=['int64']).columns
df[numerical_columns] = StandardScaler().fit_transform(df[numerical_columns])

print("Min-Max Scaled Data:")
print(df)

print("\nZ-score Normalized Data:")
print(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/macbook/Desktop/DI_bootcamp/Week_8/Day3/dc/dc_d3w7.ipynb Cell 2 line 9
#       <a href='vscode-notebook-cell:/Users/macbook/Desktop/DI_bootcamp/Week_8/Day3/dc/dc_d3w7.ipynb#W1sZmlsZQ%3D%3D?line=6'>7</a> # Select only the numerical columns for Z-score normalization
#       <a href='vscode-notebook-cell:/Users/macbook/Desktop/DI_bootcamp/Week_8/Day3/dc/dc_d3w7.ipynb#W1sZmlsZQ%3D%3D?line=7'>8</a> numerical_columns = df.select_dtypes(include=['int64']).columns
# ----> <a href='vscode-notebook-cell:/Users/macbook/Desktop/DI_bootcamp/Week_8/Day3/dc/dc_d3w7.ipynb#W1sZmlsZQ%3D%3D?line=8'>9</a> df[numerical_columns] = StandardScaler().fit_transform(df[numerical_columns])
#      <a href='vscode-notebook-cell:/Users/macbook/Desktop/DI_bootcamp/Week_8/Day3/dc/dc_d3w7.ipynb#W1sZmlsZQ%3D%3D?line=10'>11</a> print("Min-Max Scaled Data:")
# ...

# %%
# Calculate Z-scores for each numerical column
z_scores = stats.zscore(df)

# Set a Z-score threshold (e.g., 3) for identifying outliers
z_score_threshold = 3
outliers_zscore = (abs(z_scores) > z_score_threshold).any(axis=1)

# Calculate IQR for each numerical column
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1

# Set an IQR threshold (e.g., 1.5) for identifying outliers
iqr_threshold = 1.5
outliers_iqr = ((df < (Q1 - iqr_threshold * IQR)) | (df > (Q3 + iqr_threshold * IQR))).any(axis=1)

# Identify and display outliers using both methods
outliers = df[outliers_zscore | outliers_iqr]
print("Outliers using Z-score:")
print(outliers)
print("\nOutliers using IQR:")
print(outliers_iqr)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/macbook/Desktop/DI_bootcamp/Week_8/Day3/dc/dc_d3w7.ipynb Cell 3 line 2
#       <a href='vscode-notebook-cell:/Users/macbook/Desktop/DI_bootcamp/Week_8/Day3/dc/dc_d3w7.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> # Calculate Z-scores for each numerical column
# ----> <a href='vscode-notebook-cell:/Users/macbook/Desktop/DI_bootcamp/Week_8/Day3/dc/dc_d3w7.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> z_scores = stats.zscore(df)
#       <a href='vscode-notebook-cell:/Users/macbook/Desktop/DI_bootcamp/Week_8/Day3/dc/dc_d3w7.ipynb#W3sZmlsZQ%3D%3D?line=3'>4</a> # Set a Z-score threshold (e.g., 3) for identifying outliers
#       <a href='vscode-notebook-cell:/Users/macbook/Desktop/DI_bootcamp/Week_8/Day3/dc/dc_d3w7.ipynb#W3sZmlsZQ%3D%3D?line=4'>5</a> z_score_threshold = 3
#
# ...
